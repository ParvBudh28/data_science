# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
X = pd.read_csv("./Training Data/Linear_X_Train.csv").values
Y = pd.read_csv("./Training Data/Linear_Y_Train.csv").values

# %% [markdown]
# ## Steps
# 1. Save Numpy theat_list in a numpy file using np.save()
# 2. create interactive_plot.py

# %%
theta_list = np.load('theta_list.npy')
T0 = theta_list[:,0]
T1 = theta_list[:,1]

# %%
plt.ion()
# to use interactive mode

# %%
for i in range(0,50,3):
    y_ = T1[i]*X + T0
    plt.scatter(X,Y)
    plt.plot(X,y_,color='red')
    plt.draw()
    plt.pause(1)
    plt.clf() # destroys previous object
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3050a9731f84> in <module>
#       4     plt.plot(X,y_,color='red')
#       5     plt.draw()
# ----> 6     plt.pause(1)
#       7     plt.clf() # destroys previous object
#
# /Applications/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in pause(interval)
#     311             canvas.draw_idle()
#     312         show(block=False)
# --> 313         canvas.start_event_loop(interval)
#     314     else:
#     315         time.sleep(interval)
#
# /Applications/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2308         while self._looping and counter * timestep < timeout:
#    2309             self.flush_events()
# -> 2310             time.sleep(timestep)
#    2311             counter += 1
#    2312
#
# KeyboardInterrupt:
